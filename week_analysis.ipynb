# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
from wordcloud import WordCloud
from collections import Counter

# -- Week one
covid1 = pd.read_csv('datasets/covid/ds1.csv')
gp1 = pd.read_csv('datasets/gp/ds1.csv')
mgr1 = pd.read_csv('datasets/migranti/ds1.csv')
week1 = pd.concat([covid1, gp1, mgr1], axis=0)

# -- Week two
covid2 = pd.read_csv('datasets/covid/ds2.csv')
gp2 = pd.read_csv('datasets/gp/ds2.csv')
mgr2 = pd.read_csv('datasets/migranti/ds2.csv')
week2 = pd.concat([covid2, gp2, mgr2], axis=0)

# -- Week three
covid3 = pd.read_csv('datasets/covid/ds3.csv')
gp3 = pd.read_csv('datasets/gp/ds3.csv')
mgr3 = pd.read_csv('datasets/migranti/ds3.csv')
week3 = pd.concat([covid3, gp3, mgr3], axis=0)

# -- Week four
covid4 = pd.read_csv('datasets/covid/ds4.csv')
gp4 = pd.read_csv('datasets/gp/ds4.csv')
mgr4 = pd.read_csv('datasets/migranti/ds4.csv')
week4 = pd.concat([covid4, gp4, mgr4], axis=0)

# -- Week five
covid5 = pd.read_csv('datasets/covid/ds5.csv')
gp5 = pd.read_csv('datasets/gp/ds5.csv')
mgr5 = pd.read_csv('datasets/migranti/ds5.csv')
week5 = pd.concat([covid5, gp5, mgr5], axis=0)

# -- Week six
covid6 = pd.read_csv('datasets/covid/ds6.csv')
gp6 = pd.read_csv('datasets/gp/ds6.csv')
mgr6 = pd.read_csv('datasets/migranti/ds6.csv')
week6 = pd.concat([covid6, gp6, mgr6], axis=0)

# -- Week seven
covid7 = pd.read_csv('datasets/covid/ds7.csv')
gp7 = pd.read_csv('datasets/gp/ds7.csv')
mgr7 = pd.read_csv('datasets/migranti/ds7.csv')
week7 = pd.concat([covid7, gp7, mgr7], axis=0)

# %%
merge_text1 = week1["text"].tolist()
merge_text2 = week2["text"].tolist()
merge_text3 = week3["text"].tolist()
merge_text4 = week4["text"].tolist()
merge_text5 = week5["text"].tolist()
merge_text6 = week6["text"].tolist()
merge_text7 = week7["text"].tolist()

# %%
empty1 = ''
walltext1 = empty1.join(merge_text1)
splitted1 = walltext1.split()
c1 = Counter(splitted1)
c1.most_common()
# Out:
# [('di', 90),
#  ('in', 81),
#  ('e', 73),
#  ('il', 71),
#  ('la', 60),
#  ('a', 56),
#  ('per', 47),
#  ('i', 41),
#  ('al', 32),
#  ('non', 30),
#  ('Green', 29),
#  ('è', 25),
#  ('da', 25),
#  ('migranti', 24),
#  ('dei', 22),
#  ('le', 20),
#  ('del', 20),
#  ('Covid', 19),
#  ('casi', 19),
#  ('con', 17),
#  ('che', 16),
#  ('confine', 16),
#  ('della', 15),
#  ('pass', 15),
#  ('un', 14),
#  ('si', 14),
#  ('ai', 14),
#  ('#covid', 14),
#  ('No', 14),
#  ('contagi', 11),
#  ('nuovi', 11),
#  ('su', 11),
#  ('pass,', 11),
#  ('Bielorussia', 11),
#  ('morti', 10),
#  ('Danimarca', 10),
#  ('oggi', 10),
#  ('dalla', 10),
#  ('senza', 10),
#  ('Pass', 10),
#  ('Covid,', 9),
#  ('così', 9),
#  ('chi', 9),
#  ('restrizioni', 8),
#  ('dopo', 8),
#  ('riaprono', 8),
#  ('tra', 8),
#  ('nel', 8),
#  ('vaccini', 8),
#  ('cortei', 8),
#  ('terapia', 7),
#  ('dati', 7),
#  ('giorni', 7),
#  ('più', 7),
#  ('#Covid', 7),
#  ('dose', 7),
#  ('ma', 7),
#  ('alle', 7),
#  ('sul', 7),
#  ('In', 7),
#  ('centinaia', 7),
#  ('sono', 6),
#  ('dal', 6),
#  ('Covid:', 6),
#  ('24', 6),
#  ('ad', 6),
#  ('record', 6),
#  ('altri', 6),
#  ('terza', 6),
#  ('vax', 6),
#  ('reintroduce', 6),
#  ('#Danimarca', 6),
#  ('gli', 6),
#  ('vaccinati', 6),
#  ('stop', 6),
#  ('9', 6),
#  ('stretta', 6),
#  ('I', 6),
#  ('centri', 6),
#  ('#migranti', 6),
#  ('crisi', 6),
#  ('Polonia', 6),
#  ('nelle', 5),
#  ('4.197', 5),
#  ('positivi', 5),
#  ('una', 5),
#  ('mesi', 5),
#  ('aumentano', 5),
#  ('Il', 5),
#  ('boom', 5),
#  ('sui', 5),
#  ('Austria', 5),
#  ('bollettino', 5),
#  ('alla', 5),
#  ('via', 5),
#  ('storici', 5),
#  ('Singapore', 4),
#  ('persone', 4),
#  ('Italia', 4),
#  ('intensiva', 4),
#  ('ultime', 4),
#  ('prima', 4),
#  ('delle', 4),
#  ('sale', 4),
#  ('tamponi', 4),
#  ('cure', 4),
#  ('aumento:', 4),
#  ('https://t.co/ghymx0indG', 4),
#  ('anno', 4),
#  ('migliaia', 4),
#  ('contro', 4),
#  ('accelera', 4),
#  ('Ricciardi:', 4),
#  ('20', 4),
#  ('piano', 4),
#  ('altre', 4),
#  ('Europa', 4),
#  ('degli', 4),
#  ('solo', 4),
#  ('verso', 4),
#  ('fa', 4),
#  ('ricoveri', 4),
#  ('serve', 4),
#  ('nuove', 4),
#  ('tampone', 4),
#  ('basta', 4),
#  ('torna', 4),
#  ('8', 4),
#  ('mesi:', 4),
#  ('possono', 4),
#  ('anni', 4),
#  ('tasso', 4),
#  ('nei', 4),
#  ('evitare', 4),
#  ('difendere', 4),
#  ('ha', 3),
#  ('dovranno', 3),
#  ('spese', 3),
#  ('d…', 3),
#  ('ore', 3),
#  ('test', 3),
#  ('crescita', 3),
#  ('negli', 3),
#  ('100mila', 3),
#  ('15', 3),
#  ('38', 3),
#  ('positività', 3),
#  ('bambini', 3),
#  ('sulla', 3),
#  ('quarta', 3),
#  ('noi', 3),
#  ('se', 3),
#  ('Usa', 3),
#  ('fino', 3),
#  ('curva', 3),
#  ('Austria,', 3),
#  ('sulle', 3),
#  ('neonata', 3),
#  ('positiva', 3),
#  ('muore', 3),
#  ('o', 3),
#  ('governo', 3),
#  ('anti', 3),
#  ('Ema', 3),
#  ('milioni', 3),
#  ('chilometri', 3),
#  ('code', 3),
#  ('dai', 3),
#  ('madre', 3),
#  ('vaccinata', 3),
#  ('ero', 3),
#  ('intensiva,', 3),
#  ('quando', 3),
#  ('perché', 3),
#  ('fermare', 3),
#  ('contagi.', 3),
#  ('niente', 3),
#  ('ecco', 3),
#  ('già', 3),
#  ('era', 3),
#  ('frontiera', 3),
#  ('Veneto,', 3),
#  ('ministero:', 3),
#  ('decisione', 3),
#  ('come', 3),
#  ('frontiere', 3),
#  ('Germania,', 3),
#  ('mascherine', 3),
#  ('@eziomauro:', 3),
#  ('aumento,', 3),
#  ('[di', 3),
#  ('novembre:', 3),
#  ('può', 3),
#  ('cosa', 3),
#  ('Viminale:', 3),
#  ('#NoGreenpass', 3),
#  ('https://t.co/IGRAXKU6px', 3),
#  ('Viminale', 3),
#  ('Pass,', 3),
#  ('Varsavia:', 3),
#  ('respinge', 3),
#  ('«Pronti', 3),
#  ("l'aumento", 2),
#  ('lo', 2),
#  ('scelta', 2),
#  ('ammalano', 2),
#  ('pagarsi', 2),
#  ('mediche', 2),
#  ('posti', 2),
#  ('passa', 2),
#  ('Russia', 2),
#  ('supera', 2),
#  ('soglia', 2),
#  ('giorno', 2),
#  ('|', 2),
#  ('secondo', 2),
#  ('Germania:', 2),
#  ('ogni', 2),
#  ('alto', 2),
#  ('volta', 2),
#  ('decesso', 2),
#  ('collegato', 2),
#  ('_', 2),
#  ('morti.', 2),
#  ('7', 2),
#  ('#novax', 2),
#  ('https://t.co/wDJbVMHjtOCovid,', 2),
#  ('Padova', 2),
#  ('https://t.co/B7FP6lPE6x', 2),
#  ('https://t.co/BPSaxEYHjNCovid,', 2),
#  ('gialla', 2),
#  ('ondata', 2),
#  ('corso,', 2),
#  ('dipende', 2),
#  ('sarà', 2),
#  ('confini', 2),
#  ('governo:', 2),
#  ('prorogato', 2),
#  ("all'estate,", 2),
#  ('hub', 2),
#  ('zone', 2),
#  ('rosse', 2),
#  ('#Greenpass…', 2),
#  ('rispetto', 2),
#  ('giovedì', 2),
#  ('Italia.', 2),
#  ('Italia,', 2),
#  ('pandemia', 2),
#  ('dato', 2),
#  ('marzo', 2),
#  ('2020', 2),
#  ('nazionale', 2),
#  ('Bretagna,', 2),
#  ('Friuli', 2),
#  ('oltre', 2),
#  ('#Greenpass.', 2),
#  ('medici', 2),
#  ('#Germania', 2),
#  ('memoria', 2),
#  ('5', 2),
#  ('anni".', 2),
#  ('ore.', 2),
#  ('gratis', 2),
#  ('#Covid,', 2),
#  ("L'Italia", 2),
#  ('Danimarca,', 2),
#  ('mascherina', 2),
#  ('bollettino:', 2),
#  ('ne', 2),
#  ('farmaco', 2),
#  ('Lopalco:', 2),
#  ('"Lockdown', 2),
#  ('#vaccino?', 2),
#  ('Meglio', 2),
#  ('esteso".', 2),
#  ('#novax?', 2),
#  ('Non', 2),
#  ('mondo.', 2),
#  ('occhio', 2),
#  ('false', 2),
#  ('app', 2),
#  ('verifica.', 2),
#  ('Trieste,', 2),
#  ('risalita', 2),
#  ('passo', 2),
#  ('sei', 2),
#  ('#Zaia:', 2),
#  ('"Proteste?', 2),
#  ('Settimane', 2),
#  ('privazione', 2),
#  ('libertà', 2),
#  ('cittadini".#covid', 2),
#  ('Scotti', 2),
#  ('vorrei', 2),
#  ('raccontarlo', 2),
#  ('Campania,', 2),
#  ('no', 2),
#  ('pagheranno', 2),
#  ('davvero,', 2),
#  ('farla', 2),
#  ('tutti', 2),
#  ('importante', 2),
#  ('i…', 2),
#  ('lezione', 2),
#  ('misurare', 2),
#  ('anticorpi,', 2),
#  ('occorre', 2),
#  ('fare', 2),
#  ('regole', 2),
#  ('rischio', 2),
#  ('novembre', 2),
#  ('12', 2),
#  ('Gli', 2),
#  ('esperti:', 2),
#  ('nascita:', 2),
#  ('Lazio', 2),
#  ('La', 2),
#  ('regione', 2),
#  ('rischia', 2),
#  ('base', 2),
#  ('Europa:', 2),
#  ('più,', 2),
#  ('vaccini.', 2),
#  ('anti-Covid', 2),
#  ('Merck,', 2),
#  ('procedure', 2),
#  ('approvazione.', 2),
#  ('Aifa', 2),
#  ('breve', 2),
#  ('monoclonali', 2),
#  ('proteggono', 2),
#  ('infezione', 2),
#  ('funziona', 2),
#  ('«vaccinazione', 2),
#  ('passiva»', 2),
#  ('«Siamo', 2),
#  ('nella', 2),
#  ('#quarta', 2),
#  ('ondata,', 2),
#  ('forse', 2),
#  ('peggioramento', 2),
#  ('gennaio-febbraio»', 2),
#  ('Stati', 2),
#  ('Uniti', 2),
#  ('Messico', 2),
#  ('incidenza', 2),
#  ('record:', 2),
#  ('ora', 2),
#  ('lavoratori', 2),
#  ('sua', 2),
#  ('“Non', 2),
#  ('assoluto', 2),
#  ('infetti', 2),
#  ('Germania.', 2),
#  ('liberali', 2),
#  ('resistono', 2),
#  ('restrizioni.', 2),
#  ('Medici', 2),
#  ('mirino', 2),
#  ('settimanali.', 2),
#  ('Contagi', 2),
#  ('ancora', 2),
#  ('rallenta:', 2),
#  ('covid,', 2),
#  ('Covid.', 2),
#  ('Toscana', 2),
#  ('234', 2),
#  ('Cala', 2),
#  ('"I', 2),
#  ('sistema', 2),
#  ('situazione', 2),
#  ('anticovid', 2),
#  ('salire', 2),
#  ('aereo.', 2),
#  ('Nessuno', 2),
#  ('obbligarli,', 2),
#  ('procedura', 2),
#  ('rimpatrio…', 2),
#  ('Covid"', 2),
#  ('anche', 2),
#  ('dura', 2),
#  ('p…', 2),
#  ('#covid,', 2),
#  ('Treviso', 2),
#  ('200', 2),
#  ('più:', 2),
#  ('lockdown.', 2),
#  ('obbligo', 2),
#  ('vaccinale', 2),
#  ('manifestazioni', 2),
#  ('@RaiStudio24:', 2),
#  ('#NoGreenPass', 2),
#  ('30%', 2),
#  ('scuola,', 2),
#  ('Tar', 2),
#  ('centro', 2),
#  ('gialle,', 2),
#  ('pass:', 2),
#  ('anti-contagi,', 2),
#  ('escluso', 2),
#  ('lockdown', 2),
#  ('falsi', 2),
#  ('modella', 2),
#  ('hacker', 2),
#  ('circa', 2),
#  ('polacco', 2),
#  ('#Bielorussia', 2),
#  ('regime', 2),
#  ('migranti,', 2),
#  ('Polonia:', 2),
#  ('Ue', 2),
#  ('migranti:', 2),
#  ('frase', 2),
#  ('vaccinazione', 2),
#  ('figlia:', 2),
#  ('bufera', 2),
#  ('social', 2),
#  ('https://t.co/vNG92B38G5', 2),
#  ('Bielorussia,', 2),
#  ('tensione', 2),
#  ('Polonia,', 2),
#  ('medio', 2),
#  ('oriente', 2),
#  ('traffico', 2),
#  ('organizzato', 2),
#  ("L'Europa", 1),
#  ('attesa', 1),
#  ('inverno', 1),
#  ('"duro"', 1),
#  ('diversi', 1),
#  ('Paesi:', 1),
#  ('affermato', 1),
#  ('dire…', 1),
#  ('https://t.co/O9ptvWikv7A', 1),
#  ('vaccinate', 1),
#  ('https://t.co/UGc8WUrs4rTorna', 1),
#  ('risalire', 1),
#  ('percentuale', 1),
#  ('occupati', 1),
#  ('pazienti', 1),
#  ('4…', 1),
#  ('https://t.co/XYAoQKCVt7La', 1),
#  ('1.200', 1),
#  ('stati', 1),
#  ('infatti', 1),
#  ('registrat…', 1),
#  ('https://t.co/18t7E4jsmfFLASH', 1),
#  ('Sono', 1),
#  ('individuati', 1),
#  ('ore,', 1),
#  ('ministero', 1),
#  ('Sal…', 1),
#  ('https://t.co/ML7w0HLEixDopo', 1),
#  ('recente', 1),
#  ('frenata', 1),
#  ('Covid-19,', 1),
#  ('ultimi', 1),
#  ('passati', 1),
#  ('fase', 1),
#  ('accele…', 1),
#  ('https://t.co/X5ZXjou2pUNuovo', 1),
#  ('201,1', 1),
#  ('abitanti.', 1),
#  ("E'", 1),
#  ('livello', 1),
#  ("dall'inizio", 1),
#  ('pa…', 1),
#  ('https://t.co/D2aJu9XZeUPer', 1),
#  ('Giappone', 1),
#  ('registrato', 1),
#  ('alcun', 1),
#  ('Covid-19.', 1),
#  ('#ANSA', 1),
#  ('https://t.co/0vT1CIbjrw🎒I', 1),
#  ('benefici', 1),
#  ('lezioni', 1),
#  ('presenza', 1),
#  ('superano', 1),
#  ('rischi', 1),
#  ('legati', 1),
#  ('Le', 1),
#  ('chiusure', 1),
#  ('scolastiche', 1),
#  ('dall’inizio', 1),
#  ('dell…', 1),
#  ('https://t.co/QaI7rTtvpxIn', 1),
#  ('Tasso', 1),
#  ('1,7%', 1),
#  ('👇', 1),
#  ('https://t.co/KYCRYOpGnw', 1),
#  ('https://t.co/XGPv62mhKU#PierpaoloSileri', 1),
#  ('"fiducioso:', 1),
#  ('possiamo', 1),
#  ('confidare', 1),
#  ('Natale', 1),
#  ('sereno"', 1),
#  ('https://t.co/IziwWfD8u2', 1),
#  ('#agi', 1),
#  ('#CovidCovid,', 1),
#  ('6.032', 1),
#  ('654.689', 1),
#  ('68', 1),
#  ('https://t.co/I5wspHNVhR', 1),
#  ('https://t.co/VAZEWkqdmYVaccini,', 1),
#  ('mercoledì', 1),
#  ('somministrata', 1),
#  ('farmacie', 1),
#  ('lombarde', 1),
#  ('https://t.co/Ue6io0JyS8', 1),
#  ('https://t.co/9iHDnrMDlPCovid,', 1),
#  ('Agenas:', 1),
#  ('"L\'occupazione', 1),
#  ('reparto', 1),
#  ('Regioni"', 1),
#  ('#agenas', 1),
#  ('https://t.co/snfyGM7NeS', 1),
#  ('https://t.co/5cC6QGBT6wCovid,', 1),
#  ('pagherà', 1),
#  ('https://t.co/u1TQYYCHRU', 1),
#  ('https://t.co/FoYUe0zzK9Covid,', 1),
#  ('https://t.co/h6JfH2anv6Migrantes:', 1),
#  ('5,6', 1),
#  ('mln', 1),
#  ('italiani', 1),
#  ('risiedono', 1),
#  ("all'estero,", 1),
#  ('+3%', 1),
#  ('#migrantes', 1),
#  ('https://t.co/1ql89cxiKQ', 1),
#  ('https://t.co/kkP19h6G35Covid,', 1),
#  ('Nuova', 1),
#  ('Zelanda', 1),
#  ('piazza', 1),
#  ('https://t.co/B6V38wzfkT', 1),
#  ('https://t.co/2Sm3LlEGuKA', 1),
#  ('descritto', 1),
#  ('disegni', 1),
#  ('#mattinocinque', 1),
#  ('https://t.co/Q4BmRcNle3', 1),
#  ('https://t.co/v02IRtppEACovid,', 1),
#  ("l'Ema", 1),
#  ('pillola', 1),
#  ('Merck', 1),
#  ('https://t.co/uHQfOSAMhv', 1),
#  ('https://t.co/751aE1D7WSCovid,', 1),
#  ('249.115', 1),
#  ('https://t.co/jFM5IdAJrg', 1),
#  ('https://t.co/KumWyhQYVpCovid,', 1),
#  ('Fontana:', 1),
#  ('Lombardia', 1),
#  ('momento', 1),
#  ('lontana', 1),
#  ('zona', 1),
#  ('#lombardia', 1),
#  ('https://t.co/TYc1x92Ttb', 1),
#  ('https://t.co/0bU01To0veCovid,', 1),
#  ('ondina', 1),
#  ('https://t.co/8R7bSlVPDE', 1),
#  ('https://t.co/pJoVUa1VH4Covid,', 1),
#  ('https://t.co/P4rhQUeRWn', 1),
#  ('https://t.co/i85PSc1f2QCovid,', 1),
#  ('https://t.co/xZ3ofbNXJTCovid,', 1),
#  ('rallenta', 1),
#  ('settimane', 1),
#  ('https://t.co/8yJ4kDgK0q', 1),
#  ('https://t.co/zhOmjgweJICovid,', 1),
#  ('nuovo', 1),
#  ('negativo', 1),
#  ('abitanti', 1),
#  ('#germania', 1),
#  ('https://t.co/PTeyh1NWCN', 1),
#  ('https://t.co/Ii2WX61s4wCovid,', 1),
#  ('Giappone:', 1),
#  ('nessun', 1),
#  ('https://t.co/tkF7j4Zt9L', 1),
#  ('https://t.co/DuBoqx1iGn#Covid,', 1),
#  ('Israele', 1),
#  ("all'esterno.", 1),
#  ('https://t.co/PQ6VFhMt3JI', 1),
#  ('https://t.co/rtglBJTMQn#Covid', 1),
#  ("l'offerta", 1),
#  ('bordello', 1),
#  ('Vienna', 1),
#  ('incentivare', 1),
#  ('#vaccini.', 1),
#  ('https://t.co/bCngRFeIrl#Covid', 1),
#  ('"troppi', 1),
#  ('rispettano', 1),
#  ('#misure:', 1),
#  ('preoccupano', 1),
#  ('aeroporti".', 1),
#  ('https://t.co/6KEdL7ybVt#Covid', 1),
#  ('Gb,', 1),
#  ("l'impatto", 1),
#  ('casa:', 1),
#  ('ottobre', 1),
#  ('2021.', 1),
#  ('https://t.co/1CwDkuY4dQ21°', 1),
#  ('meeting', 1),
#  ('Aiic', 1),
#  ('Milano', 1),
#  ('Pnrr', 1),
#  ('Ssn', 1),
#  ('post-Covid.', 1),
#  ('https://t.co/Sna3TnIFPrGran', 1),
#  ('nascita.', 1),
#  ('https://t.co/BpkZiCvAcg#Covid,', 1),
#  ('ricompense', 1),
#  ('cambio', 1),
#  ('‘soffiate’:', 1),
#  ('Cina', 1),
#  ("l'ultima", 1),
#  ('strategia', 1),
#  ('guerra', 1),
#  ('#virus.', 1),
#  ('https://t.co/1U6VWsOtf8#Covid,', 1),
#  ('Marche', 1),
#  ('#intensive', 1),
#  ('11%:', 1),
#  ('allerta.', 1),
#  ('https://t.co/4RY6jtXuxe#Covid', 1),
#  ('Francia,', 1),
#  ('discorso', 1),
#  ('Macron:', 1),
#  ('incognita', 1),
#  ('https://t.co/vuNIWTUFKO#Covid,', 1),
#  ('sospesi', 1),
#  ('1.656', 1),
#  ('#vaccino', 1),
#  ('https://t.co/RkEaxa00dL#Covid,', 1),
#  ('l’incidenza', 1),
#  ('213:', 1),
#  ('picco', 1),
#  ('inizio', 1),
#  ('pandemia.', 1),
#  ('https://t.co/weK3KvbIRL#Covid', 1),
#  ('Abrignani:', 1),
#  ('"Con', 1),
#  ('#terzadose', 1),
#  ('immunitaria', 1),
#  ('10', 1),
#  ('https://t.co/FFlgJRgQvt#Covid,', 1),
#  ('decessi', 1),
#  ('#Ucraina:', 1),
#  ('833', 1),
#  ('Mai', 1),
#  ('tanti.', 1),
#  ('https://t.co/EJAFePTDJh#Covid,', 1),
#  ('#vaccino:', 1),
#  ('ammala', 1),
#  ('dovrà', 1),
#  ('mediche.', 1),
#  ('https://t.co/p8v9JaEh6n#Statodiemergenza', 1),
#  ('ipotesi', 1),
#  ('proroga', 1),
#  ('2022', 1),
#  ('vicina.', 1),
#  ('https://t.co/rF9yTUSS59#Covid,', 1),
#  ('prese', 1),
#  ('ondata:', 1),
#  ('numeri.', 1),
#  ('intanto', 1),
#  ('#terzadose.', 1),
#  ('https://t.co/ebOdukvMED#Covid', 1),
#  ('valuta', 1),
#  ('ritorno', 1),
#  ('https://t.co/alpVwS4qcp#Covid,', 1),
#  ('Boris', 1),
#  ('Johnson', 1),
#  ('ospedale:', 1),
#  ('polemica', 1),
#  ('#Gb.', 1),
#  ('https://t.co/vIPZbIl9hY#CovidGb,', 1),
#  ('oggi.', 1),
#  ('https://t.co/4Dh7T0sx6j#Covid,', 1),
#  ('pediatri:', 1),
#  ('"#Vaccino', 1),
#  ('usciamo.', 1),
#  ('20%', 1),
#  ('contagiati', 1),
#  ('sotto', 1),
#  ('11', 1),
#  ('https://t.co/9Ier1sHlYV#Covid,', 1),
#  ('#Usa', 1),
#  ('turisti:', 1),
#  ('prenotazioni.', 1),
#  ('https://t.co/bZXAHRLD5lPillola', 1),
#  ('avvia', 1),
#  ('revisione', 1),
#  ('Merck.', 1),
#  ('https://t.co/FchpyRHu3V#Covid,', 1),
#  ('Pregliasco:', 1),
#  ('"Io', 1),
#  ('vittima', 1),
#  ('infangamento', 1),
#  ('pazzesco', 1),
#  ('social".', 1),
#  ('https://t.co/SYcJMjGP8iI', 1),
#  ('https://t.co/t1K8WelBzJ#Covid,', 1),
#  ('https://t.co/3oVJ0Tf7c7#Covid,', 1),
#  ('Galli:', 1),
#  ('"No', 1),
#  ('Assurdo,', 1),
#  ('salvano', 1),
#  ('vite".', 1),
#  ('https://t.co/x6C2R6TDdh#Covid,', 1),
#  ('Crisanti:', 1),
#  ('"Cure', 1),
#  ('pagamento', 1),
#  ('Suggestivo', 1),
#  ('pericoloso.', 1),
#  ('Lockdown', 1),
#  ('vaccinati?', 1),
#  ('nessun…', 1),
#  ('https://t.co/uChfuQ8nBWSuperati', 1),
#  ('250', 1),
#  ('https://t.co/76yvC3GPdCTerza', 1),
#  ('dose,', 1),
#  ('#Figliuolo:', 1),
#  ('"Presto', 1),
#  ('abbasseremo', 1),
#  ('età".', 1),
#  ('https://t.co/uDNeW2jPE4Covid,', 1),
#  ('Andreoni', 1),
#  ('“serve', 1),
#  ('#Greenpass:', 1),
#  ('guariti".', 1),
#  ('https://t.co/Kj6bI0ZteVGreen', 1),
#  ('https://t.co/TbWs1QNCMpContagi', 1),
#  ('sindaco:', 1),
#  ('“Colpa', 1),
#  ('manifestazioni,', 1),
#  ('servirebbe', 1),
#  ('#obbligovaccino”.', 1),
#  ('https://t.co/uvn5MMRQwu"Più', 1),
#  ('contagi",', 1),
#  ('Gimbe.', 1),
#  ('https://t.co/BJwG92L4TfRiapre', 1),
#  ('#Transatlantico,', 1),
#  ('Fico:', 1),
#  ('"Piccolo', 1),
#  ('normalità".', 1),
#  ('#Covid.', 1),
#  ('https://t.co/5CUrxwtdOb#Covid,', 1),
#  ('Svizzera', 1),
#  ('prova', 1),
#  ('convincere', 1),
#  ('indecisi', 1),
#  ("l'ipnosi.", 1),
#  ('https://t.co/GxZUi6qHRh“A', 1),
#  ('morte', 1),
#  ('#Bassetti”.', 1),
#  ('Ancora', 1),
#  ('minacce', 1),
#  ('l’infettivologo:', 1),
#  ('“Stato', 1),
#  ('ci', 1),
#  ('batti', 1),
#  ('colpo".', 1),
#  ('https://t.co/qJNKrpM2Hy#Covid', 1),
#  ('vigore', 1),
#  ('#restrizioni', 1),
#  ('#vaccino.', 1),
#  ('https://t.co/0IxzF2PNhL#Covid,', 1),
#  ('"#Quartaondata', 1),
#  ('ridurla".', 1),
#  ('https://t.co/8NQW7shjTmGreen', 1),
#  ('https://t.co/fwfiblY8ZL#Covid,', 1),
#  ('#frontiere', 1),
#  ('#vaccinati:', 1),
#  ('Messico.', 1),
#  ('https://t.co/ebg7S4DZkK#Covid,', 1),
#  ('Sileri', 1),
#  ('"L\'immunità', 1),
#  ('data', 1),
#  ('va', 1),
#  ('rafforzata.', 1),
#  ("L'ulteriore", 1),
#  ('richiamo', 1),
#  ('strano,', 1),
#  ('anzi', 1),
#  ('comune', 1),
#  ('tutti…', 1),
#  ('https://t.co/va91N7EqGtMuore', 1),
#  ('nove', 1),
#  ('aver', 1),
#  ('contratto', 1),
#  ('https://t.co/etINL0Xtum', 1),
#  ('https://t.co/U2RdqzZES0Gerry', 1),
#  ('https://t.co/0S0G4AseGqGerry', 1),
#  ('...', 1),
#  ('https://t.co/7e6UAqnwo9', 1),
#  ('https://t.co/Oa3w365kQlCovid', 1),
#  ('493', 1),
#  ('https://t.co/BepvoGOvvbCovid', 1),
#  ('393', 1),
#  ('quattro', 1),
#  ('morti:', 1),
#  ("l'indice", 1),
#  ('contagio', 1),
#  ('stabile', 1),
#  ('3,47%', 1),
#  ('https://t.co/DU8CCqDhy4Covid.', 1),
#  ('Singapore:', 1),
#  ('cure.', 1),
#  ('403', 1),
#  ('https://t.co/ncG2AMOoxJNon', 1),
#  ('arresta', 1),
#  ('domenica', 1),
#  ('registrare', 1),
#  ('5.822', 1),
#  ('26', 1),
#  ('decessi,', 1),
#  ('tass…', 1),
#  ('https://t.co/gSTKO1QNgJTerza', 1),
#  ('https://t.co/2ECuZmM7xPCovid,', 1),
#  ('corsa', 1),
#  ('Francia', 1),
#  ('Inghilterra:', 1),
#  ('https://t.co/nLbAfc6DxMCovid,', 1),
#  ('@RobertoBurioni', 1),
#  ('terza…', 1),
#  ('https://t.co/fLsGyuxQJOTerza', 1),
#  ('https://t.co/4AF5aID09vCovid,', 1),
#  ('Gerry', 1),
#  ('Scotti:', 1),
#  ('“Un', 1),
#  ('ricordo', 1),
#  ('nega”', 1),
#  ('https://t.co/yx2bl9V5rzScuola,', 1),
#  ('gestione', 1),
#  ('quarantena', 1),
#  ('https://t.co/V9zt2xNApdConcessionari,', 1),
#  ('Federauto:', 1),
#  ('delicati', 1),
#  ('equilibri', 1),
#  ('reti', 1),
#  ('#vendita', 1),
#  ('penalizzata', 1),
#  ('covid', 1),
#  ('https://t.co/HU1skwwBLM#covid', 1),
#  ('#bambini,', 1),
#  ('Gaslini', 1),
#  ('#genova', 1),
#  ('studio', 1),
#  ('conseguenze', 1),
#  ('virus.', 1),
#  ('Cosa', 1),
#  ('sappiamo', 1),
#  ('https://t.co/VsD6YGnDkHCovid', 1),
#  ('Lazio,', 1),
#  ('2021:', 1),
#  ('773', 1),
#  ('(343', 1),
#  ('Roma)', 1),
#  ('https://t.co/hxpj5nsoxWCovid,', 1),
#  ('influenza.', 1),
#  ('«Vaccino', 1),
#  ('fondamentale,', 1),
#  ('fatelo', 1),
#  ('insieme', 1),
#  ('dose»', 1),
#  ('https://t.co/snSJG7Y4LzCovid,', 1),
#  ('https://t.co/5rj25i7gm8Covid,', 1),
#  ('azzerata', 1),
#  ('mortalità', 1),
#  ('eccesso.', 1),
#  ('passare', 1),
#  ('giallo', 1),
#  ('https://t.co/j1LsLdZ6QrVaccini', 1),
#  ('proteine', 1),
#  ('nuova', 1),
#  ('combattere', 1),
#  ('Covid?', 1),
#  ('risultati', 1),
#  ('incoraggianti', 1),
#  ('ricerca', 1),
#  ('https://t.co/3Zf8sklRKACovid', 1),
#  ('balzo', 1),
#  ('contagi:', 1),
#  ('raddoppiati', 1),
#  ('prima,', 1),
#  ('(anche)', 1),
#  ("https://t.co/e1ZM5uirbRL'ondata", 1),
#  ('https://t.co/ETrd4IJPL7Pillola', 1),
#  ('https://t.co/JVc5DxtKTZCovid,', 1),
#  ('https://t.co/EZK6zZfI9BCovid,', 1),
#  ('https://t.co/HiFq1FdB3qCovid,', 1),
#  ('https://t.co/rdiIg85yD6Covid', 1),
#  ('https://t.co/iyPBtbMloPContagi', 1),
#  ('Cauda', 1),
#  ('(Gemelli):', 1),
#  ('«Troppi', 1),
#  ('assembramenti,i', 1),
#  ('infettarsi:', 1),
#  ("all'aperto»", 1),
#  ('https://t.co/ZLyeCPgCwcContagi', 1),
#  ('Cartabellotta:', 1),
#  ('«Un', 1),
#  ('milione', 1),
#  ('dosi', 1),
#  ('settimana,', 1),
#  ('saremo', 1),
#  ('sicurezza»', 1),
#  ('https://t.co/yBSp62XYXGIl', 1),
#  ('mai', 1),
#  ('alto:', 1),
#  ('1.155', 1),
#  ('covid-19,', 1),
#  ('503', 1),
#  ('abitanti,', 1),
#  ('settimana.', 1),
#  ('È', 1),
#  ('"il', 1),
#  ('prezzo', 1),
#  ('70', 1),
#  ('mila…', 1),
#  ('https://t.co/wTsWM51hkJA', 1),
#  ('novax', 1),
#  ('contraggono', 1),
#  ('ospedaliere.', 1),
#  ('spingere…', 1),
#  ('https://t.co/tAQHa7vy1uCovid,', 1),
#  ('Ocse:', 1),
#  ('“In', 1),
#  ('l’aspettativa', 1),
#  ('vita', 1),
#  ('calata', 1),
#  ('1,2', 1),
#  ('durante', 1),
#  ('pandemia”', 1),
#  ('https://t.co/5uAfpmKcbJCovid,', 1),
#  ('ultimatum', 1),
#  ('Londra', 1),
#  ('Rsa:', 1),
#  ('entro', 1),
#  ('doppia', 1),
#  ('dose.', 1),
#  ('“Se', 1),
#  ('perderanno', 1),
#  ('50mila', 1),
#  ('6…', 1),
#  ('https://t.co/gkObWWNycVIn', 1),
#  ('pubblico', 1),
#  ('aveva', 1),
#  ('spiegato', 1),
#  ('innocenza:', 1),
#  ('scherziamo', 1),
#  ('(…).', 1),
#  ('Era', 1),
#  ('dare', 1),
#  ('mano', 1),
#  ('all’emergenza', 1),
#  ('Covid”.', 1),
#  ('Giugn…', 1),
#  ('https://t.co/7GoLWJFJ9LCovid,', 1),
#  ('l’immunologo', 1),
#  ('Abrignani', 1),
#  ('(Cts):', 1),
#  ('“Terza', 1),
#  ('vaccino', 1),
#  ('innescare', 1),
#  ('consenta', 1),
#  ('richiami', 1),
#  ('https://t.co/7IgJx8wqYbCovid,', 1),
#  ('scoprì', 1),
#  ('cura', 1),
#  ('dell’artrite', 1),
#  ('reumatoide', 1),
#  ('efficace.', 1),
#  ('medico:', 1),
#  ('“M…', 1),
#  ('https://t.co/95vdOv0rtLCovid,', 1),
#  ('quasi', 1),
#  ('600', 1),
#  ('Transatlantico', 1),
#  ('buvette', 1),
#  ('Camera:', 1),
#  ('video', 1),
#  ('https://t.co/2wJkP3ycxD“Milano', 1),
#  ('dimentica”:', 1),
#  ('coreografia', 1),
#  ('Milan', 1),
#  ('–', 1),
#  ('FOTO', 1),
#  ('https://t.co/4mJKrEHbL1Vaccini,', 1),
#  ('Nfl', 1),
#  ('touchdown:', 1),
#  ('bugie', 1),
#  ('superstar', 1),
#  ('Rodgers', 1),
#  ('"cura', 1),
#  ('alternativa".', 1),
#  ('Sconcerto', 1),
#  ('Usa…', 1),
#  ('https://t.co/qTGDQjWHvFCovid,', 1),
#  ('32', 1),
#  ('Aumentano', 1),
#  ('terapie', 1),
#  ('intensive', 1),
#  ...]

# %%
empty2 = ''
walltext2 = empty2.join(merge_text2)
splitted2 = walltext2.split()
c2 = Counter(splitted2)
c2.most_common()

# %%
empty3 = ''
walltext3 = empty3.join(merge_text3)
splitted3 = walltext3.split()
c3 = Counter(splitted3)
c3.most_common()

# %%
empty4 = ''
walltext4 = empty4.join(merge_text4)
splitted4 = walltext4.split()
c4 = Counter(splitted4)
c4.most_common()

# %%
empty5 = ''
walltext5 = empty5.join(merge_text5)
splitted5 = walltext5.split()
c5 = Counter(splitted5)
c5.most_common()

# %%
empty6 = ''
walltext6 = empty6.join(merge_text6)
splitted6 = walltext6.split()
c6 = Counter(splitted6)
c6.most_common()

# %%
empty7 = ''
walltext7 = empty7.join(merge_text7)
splitted7 = walltext7.split()
c7 = Counter(splitted7)
c7.most_common()

# %%
wc1 = {'Covid': 76, 'pass': 51, 'Green': 39, 'migranti': 34, 'contagi': 20, 'casi': 19, 'Danimarca': 18,  'confine': 16, 'Bielorussia': 15, 'vax': 11}
wc2 = {'Covid': 94, 'pass': 40, 'Green': 30, 'contagi': 28, 'casi': 25, 'migranti': 24, 'vaccino': 19, 'Bielorussia': 17, 'oggi': 17, 'vaccinati': 16}
wc3 = {'Covid': 148, 'pass': 85, 'Green': 60, 'contagi': 40, 'oggi': 36, 'morti': 30, 'migranti': 27, 'novembre': 25, 'vaccino': 25, 'casi': 21}
wc4 = {'Covid': 181, 'pass': 106, 'Green': 78, 'casi': 41, 'Italia': 41, 'contagi': 39, 'migranti': 35, 'lockdown': 34, 'morti': 33, 'vax': 33}
wc5 = {'Covid': 231, 'pass': 130, 'Green': 112, 'variante': 51, 'super': 51, 'morti': 40, 'contagi': 35, 'migranti': 34, 'casi': 31,  'Italia': 28}
wc6 = {'Covid': 170, 'pass': 51, 'Omicron': 42, 'Green': 39, 'positivi': 30, 'oggi': 30, 'contagi': 29, 'morti': 26, 'casi': 26, 'variante': 22}
wc7 = {'Covid': 204, 'pass': 57, 'Green': 48, 'Italia': 43, 'vaccino': 42, 'casi': 41, 'oggi': 37, 'Omicron': 30, 'morti': 29, 'dicembre': 28}

# %%
wc_1 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc1)
plt.axis('off')
plt.title('Wordcloud week 1')
plt.imshow(wc_1)

# %%
wc_2 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc2)
plt.axis('off')
plt.title('Wordcloud week 2')
plt.imshow(wc_2)

# %%
wc_3 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc3)
plt.axis('off')
plt.title('Wordcloud week 3')
plt.imshow(wc_3)

# %%
wc_4 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc4)
plt.axis('off')
plt.title('Wordcloud week 4')
plt.imshow(wc_4)

# %%
wc_5 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc5)
plt.axis('off')
plt.title('Wordcloud week 5')
plt.imshow(wc_5)

# %%
wc_6 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc6)
plt.axis('off')
plt.title('Wordcloud week 6')
plt.imshow(wc_6)

# %%
wc_7 = WordCloud(background_color="black",width=3000,height=2000, max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(wc7)
plt.axis('off')
plt.title('Wordcloud week 7')
plt.imshow(wc_7)
